# %%
students_records = {
    'std_1' : {'name':'usama_naeem',
               'roll_no':'fa21-164-bscs'},
    
    'std_2' : {'name':'ghaffir_ahmed',
               'roll_no':'fa21-165-bscs'}
}
print(students_records)
# Out:
# {'std_1': {'name': 'usama_naeem', 'roll_no': 'fa21-164-bscs'}, 'std_2': {'name': 'ghaffir_ahmed', 'roll_no': 'fa21-165-bscs'}}

# %%
#query: extract the name of student 1 and student 2 name from students_records dictionary
# print(students_records['std_1']['name'],',',students_records['std_2']['name'])

for key,value in students_records.items():
    print(value['name'])
# Out:
# usama_naeem
# ghaffir_ahmed
