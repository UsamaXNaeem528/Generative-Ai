# %%
empty_list = []
if empty_list:
    print(True)
else:
    print(False)
# Out:
# False

# %%
mixed_letter_list = ['a','c','5','e','9','f','10','h','n']
print(mixed_letter_list)
# Out:
# ['a', 'c', '5', 'e', '9', 'f', '10', 'h', 'n']

# %%
mixed_letter_list[0:4:2]
# Out:
# ['a', '5']

# %%
new_lst = mixed_letter_list.copy()
print(new_lst)
# Out:
# ['a', 'c', '5', 'e', '9', 'f', '10', 'h', 'n']

# %%
new_lst is mixed_letter_list
# Out:
# False

# %%
mixed_letter_list
# Out:
# ['a', 'c', '5', 'e', '9', 'f', '10', 'h', 'n']

# %%
mixed_letter_list.append(11)
mixed_letter_list
# Out:
# ['a', 'c', '5', 'e', '9', 'f', '10', 'h', 'n', 11, 11]

# %%
mixed_letter_list.remove('a')

# %%
mixed_letter_list
# Out:
# ['c', '5', 'e', '9', 'f', '10', 'h', 'n', 11, 11]

# %%
mixed_letter_list.insert(2,'usama')

# %%
mixed_letter_list
# Out:
# ['c', '5', 'usama', 'e', '9', 'f', '10', 'h', 'n', 11, 11]
