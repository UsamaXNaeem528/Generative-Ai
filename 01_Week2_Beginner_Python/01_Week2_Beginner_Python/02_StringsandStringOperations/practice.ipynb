# %%
name = "Usama"
age = 24
field = "Software Engineering"

print(f"MyName is {name} , Age is {24} and field is {field}")
# Out:
# MyName is Usama , Age is 24 and field is Software Engineering

# %%
routine = '''Morning --> Office 
After Noon --> Office Lunch
Night --> Practice Python'''
print(routine)
# Out:
# Morning --> Office
# After Noon --> Office Lunch
# Night --> Practice Python

# %%
hobby = "coding"
goal = "AI engineer"
print(f'My Hobby is {hobby} and my goal is {goal}')
# Out:
# My Hobby is coding and my goal is AI engineer

# %%
print("Python" * 10)
# Out:
# PythonPythonPythonPythonPythonPythonPythonPythonPythonPython

# %%
seq = "I am learning Python"
print(len(seq))
# Out:
# 20

# %%
text = "Artificial"
print(text[0])
print(text[-1])
print(text[2])
print(text[-3])
# Out:
# A
# l
# t
# i

# %%
text = "GenerativeAI"
print(text[0:5])
print(text[-3:])
# Out:
# Gener
# eAI

# %%
msg = "  Hello Python World  "
print(msg.lower())
print(msg.upper())
print(msg.strip())
print(msg.replace('Python', 'Ai'))
# Out:
#   hello python world
#   HELLO PYTHON WORLD
# Hello Python World
#   Hello Ai World

# %%
sentence = "Python is very powerful language for Ai and ML"
sentence.split(" ")
# Out:
# ['Python', 'is', 'very', 'powerful', 'language', 'for', 'Ai', 'and', 'ML']

# %%
print("Python \nis \neasy")
# Out:
# Python
# is
# easy

# %%
#string join method
parts = ['hello', 'world']
my_str = ' '.join(parts)
print(my_str)
# Out:
# hello world

# %%
total = 25
if "total >=50" or "vip":
    print("Free Shipping")
else:
    print("Pay Shipping")
# Out:
# Free Shipping

# %%
name = "a"

if name:
    print(True)
else:
    print(False)
# Out:
# True
