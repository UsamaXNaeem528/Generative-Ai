# %%
def print_all(*unknown):
    return unknown

print_all('usama','naeem','hello')
# Out:
# ('usama', 'naeem', 'hello')

# %%
def add_user(**info):
    for key, value in info.items():
            return(f'{key} ==> {value}')

# %%
add_user(name='Usama', field='Ai')
# Out:
# 'name ==> Usama'

# %%
nums = [1,3,5,7,9]
square = list(map(lambda x : x**2, nums)) #*maps the nums list to expression to find square. 
print(type(square))
# Out:
# <class 'list'>

# %%
nums = ["10", "20", "30"]

int_map = list(map(lambda x: int(x), nums))
print(int_map)
# Out:
# [10, 20, 30]

# %%
cars = {
    "Suzuki Alto": 660,
    "Honda Civic": 1800,
    "Toyota Corolla": 1300,
    "Suzuki Mehran": 800,
    "Honda City": 1500
}

# %%
new_cars = list(filter(lambda x: x[1]>1100, cars.items()))

# %%
new_cars
# Out:
# [('Honda Civic', 1800), ('Toyota Corolla', 1300), ('Honda City', 1500)]

# %%
'''
Sort the employees by:
Department (alphabetically),
Then by salary (descending) within each department.
'''

employees = [
    {'name': 'Alice', 'department': 'HR', 'salary': 50000},
    {'name': 'Bob', 'department': 'Engineering', 'salary': 80000},
    {'name': 'Charlie', 'department': 'HR', 'salary': 60000},
    {'name': 'David', 'department': 'Engineering', 'salary': 75000},
    {'name': 'Eve', 'department': 'Marketing', 'salary': 70000}
]

# %%
sorted_emp = sorted(employees, key=lambda x : (x['department'],-x['salary']))

# %%
sorted_emp
# Out:
# [{'name': 'Bob', 'department': 'Engineering', 'salary': 80000},
#  {'name': 'David', 'department': 'Engineering', 'salary': 75000},
#  {'name': 'Charlie', 'department': 'HR', 'salary': 60000},
#  {'name': 'Alice', 'department': 'HR', 'salary': 50000},
#  {'name': 'Eve', 'department': 'Marketing', 'salary': 70000}]

# %%
def print_user_info(**info):
    for key, value in info.items():
        return(f'{key} ==> {value}')
        
print("User Information")
print(print_user_info(name='Usama Naeem', age='23', interst='Artificial Intelligence'))
# Out:
# User Information
# name ==> Usama Naeem

# %%
lst = [1,2,3,4,5,6,'usama',10]
# print(len(lst))
# Out:
# 8

# %%
lst[0:7:2]
# Out:
# [1, 3, 5, 'usama']

# %% [markdown]
# Square and Sort the list
# nums = [7, 2, 5, 1, 4]

# %%
nums = [7, 2, 5, 1, 4]
nums = list(sorted((map(lambda x:x*x, nums))))
nums
# Out:
# [1, 4, 16, 25, 49]

# %% [markdown]
# Filter Even numbers nums = [10, 15, 22, 31, 40, 55]

# %%
def filter_even(num):
    if num%2==0:
        return num

# %%
nums = [10, 15, 22, 31, 40, 55]

# %%
even_nums = list(filter(filter_even, nums))

# %%
even_nums
# Out:
# [10, 22, 40]

# %% [markdown]
# Sort by Length
# words = ["python", "ai", "developer", "code"]

# %%
words = ["python", "ai", "developer", "code"]

sorted(words, key=lambda x: len(x))
# Out:
# ['ai', 'code', 'python', 'developer']

# %%
# 6. Square Only Odd Numbers
nums = [1, 2, 3, 4, 5, 6, 7]

odds = filter(lambda x: x%2!=0, nums)
odd_square = list(map(lambda x:x*x, odds))
odd_square
# Out:
# [1, 9, 25, 49]

# %%
lst = ['c', 'd', 'a', 'e', 'b']
sorted(lst)
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
std_info = {
    165 : {
        'name' : 'usama',
        'email'  : 'dsgusama@gmail.com'
    }
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[73], line 2
#       1 std_info = {
# ----> 2     std_info[12] == {
#       3         'name' : 'usama',
#       4         'email'  : 'dsgusama@gmail.com'
#       5     }
#       6 }
#
# NameError: name 'std_info' is not defined
